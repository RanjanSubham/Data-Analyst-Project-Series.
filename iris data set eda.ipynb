# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ir = pd.read_csv(r"D:\internship\Iris.csv")

# %%
ir
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
ir.shape
# Out:
# (150, 6)

# %%
ir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
ir.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
ir.corr(numeric_only = True)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sns.heatmap(ir.corr(numeric_only= True),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # NO null value inside this dataset

# %%
features_with_na = [features for features in ir.columns if ir[features].isnull().sum()>1]
for ft in features_with_na:
    print(ft,np.round(ir[ft].isnull().mean()*100,4), '% missing values ')

# %%
ir.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.heatmap(ir.isnull())
# Out:
# <Axes: >

# %%
ir.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.figure(figsize=(17,9))
plt.title("Comparison between various species based on sapel length and width")
sns.scatterplot(x = "SepalLengthCm",y = "SepalWidthCm",hue="Species",data = ir)
# Out:
# <Axes: title={'center': 'Comparison between various species based on sapel length and width'}, xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
plt.figure(figsize=(17,9))
plt.title("Comparison between various species based on Petal length and width")
sns.scatterplot(x = "PetalLengthCm",y = "PetalWidthCm",hue="Species",data = ir)
# Out:
# <Axes: title={'center': 'Comparison between various species based on Petal length and width'}, xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.lineplot(x = "SepalLengthCm",y = "SepalWidthCm",data = ir)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
ir["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
sns.countplot(x = "Species",data =ir)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
sns.pairplot(ir,hue="Species",height=4)

# %%
ir.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.boxplot( y="PetalWidthCm", x= "Species", data=ir, orient="v" , ax=axes[0, 0])
sns.boxplot( y="PetalLengthCm", x= "Species", data=ir, orient="v" , ax=axes[0, 1])
sns.boxplot( y="SepalLengthCm", x= "Species", data=ir, orient="v" , ax=axes[1, 0])
sns.boxplot( y="SepalWidthCm", x= "Species", data=ir, orient="v" , ax=axes[1, 1])
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.violinplot( y="PetalWidthCm", x= "Species", data=ir, orient="v" , ax=axes[0, 0])
sns.violinplot( y="PetalLengthCm", x= "Species", data=ir, orient="v" , ax=axes[0, 1])
sns.violinplot( y="SepalLengthCm", x= "Species", data=ir, orient="v" , ax=axes[1, 0])
sns.violinplot( y="SepalWidthCm", x= "Species", data=ir, orient="v" , ax=axes[1, 1])
plt.show()

# %%
sns.histplot(data=ir,x="SepalLengthCm",hue="Species",kde = True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(data=ir,x="SepalWidthCm",hue="Species",kde = True)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(data=ir,x="PetalLengthCm",hue="Species",kde = True)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(data=ir,x="PetalWidthCm",hue="Species",kde = True)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>
